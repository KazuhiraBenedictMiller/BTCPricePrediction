# %% [markdown]
# # Exploratory Data Analysis

# %%
#Let's build a simple interactive Line Chart for our Cleaned Data

# %% [markdown]
# # Importing necessary libraries

# %%
import pandas as pd

import sys
sys.path.append("../scripts/")
import path

# %% [markdown]
# # Importing Transformed Data

# %%
CleanData = pd.read_parquet(path.TRANSFORMED_DATA_DIR / "BTC-USD_HourlyTransformedData_From2021-12-14 00:00:00+00:00_To2024-01-09 23:00:00+00:00.parquet")

CleanData
# Out:
#                            Date     Close
# 298   2021-12-14 00:00:00+00:00  47022.75
# 297   2021-12-14 01:00:00+00:00  46889.47
# 296   2021-12-14 02:00:00+00:00  47052.39
# 295   2021-12-14 03:00:00+00:00  46977.81
# 294   2021-12-14 04:00:00+00:00  47017.01
# ...                         ...       ...
# 17940 2024-01-09 19:00:00+00:00  46890.10
# 17939 2024-01-09 20:00:00+00:00  46651.31
# 17938 2024-01-09 21:00:00+00:00  45419.45
# 17937 2024-01-09 22:00:00+00:00  46278.06
# 17936 2024-01-09 23:00:00+00:00  46124.08
#
# [18168 rows x 2 columns]

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# %%
output_notebook()
p = figure(title="BTC-USD Price Chart", x_axis_label='Date', x_axis_type="datetime", y_axis_label='Hourly plot_width=1000,Close Price', width=1300)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="edce93b8-7eb6-4975-a6a9-43624319403c">Loading BokehJS ...</span>
#     </div>

# %%
p.line(CleanData["Date"], CleanData["Close"], legend_label="BTC-USD", line_width=2, color="black")
# Out:
# GlyphRenderer(id='p1052', ...)

# %%
show(p)
# Out:
#   <div id="d2801461-32da-4fd3-93dd-12453c2000d1" data-root-id="p1001" style="display: contents;"></div>
